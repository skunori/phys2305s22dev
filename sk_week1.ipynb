# %%
a=2+3
print(a)
# Out:
# 5

# %%
b=7+8
c=a+b
print(b)
print(c)
# Out:
# 15
# 20

# %%
import print("Hello, World!") as np
import matplotlib.pyplot as plt
x=np.arange(0.0, 20.0, 0.1)
y=np.sin(x)
plt.plot(x,y)
plt.show()

# %%
print("Hello, World xyz !")
# Out:
# Hello, World xyz !

# %%
if 5 > 3:
  print("Five is greater than two!")
  print("this is second line.")
# Out:
# Five is greater than two!
# this is second line.

# %%
x = 5
y = "Hello, World!"

# %%
# this is a comment line
# print(x)
print(y)
# Out:
# Hello, World!
